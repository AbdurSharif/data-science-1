# %%
# !pip install "preliz[full,notebook]"

# %%
import preliz as pz

# %% [markdown]
# # Unit 3 Exercises: Delightfully Diverse Distirbutions
#
# Use these exercises as a chance to explore the probability distributions (dists) from the pymc and preliz libraries. [Moments](https://en.wikipedia.org/wiki/Moment_(mathematics)), the main subject of these exercises, are a great way to describe dists, but there's another  way: [maximum entropy](https://en.wikipedia.org/wiki/Maximum_entropy_probability_distribution#Other_examples), which  we'll cover in a later unit.
#
# Here's what we'll cover in this Unit's exercises:
# - The first four moments: mean, variance, skew, and kurtosis, as well as the support.
# - Single variable continuous distributions.
# - Single variable discrete distriutions
#
#
# Why do we need to know this stuff? Two reasons:
# - Probability distributions are required to set priors and likelihoods in pymc.
# - Randomness and uncertainty are not well defined mathematically, but probability and probability distributions are.
#
# With that in mind, think of these exercises as an oppurtunity to explore the ways we can be uncertain, or the ways things can be random.

# %% [markdown]
# ## The First Four Moments: Mean, Variance, Skew, and Kurtosis
#
# When we talk about a probablity dist, we often care about at four things:
# - The expected value, or where a distribution is centered (mean)
# - The amount of variation from that centered value (variation)
# - Whether or not our distribution favors, leans towards, or skews towards certain values. (skew)
# - How often to expect unusually high or low values. (kurtosis)

# %% [markdown]
# ### Playing with Beta

# %% [markdown]
# **Task1**:
#
# Plot a [preliZ Beta distribution](https://preliz.readthedocs.io/en/latest/api_reference.html#preliz.distributions.beta.Beta) with $α=1$ and $β=1$.

# %%
pz.Beta(alpha=1,beta=1).plot_pdf()
# Out:
# <Axes: >

# %% [markdown]
# **Task2**:
#
# Find the mean, variance, skew, and kurtosis of a $Beta(1,1)$ distribution. This is the same as asking for the first four moments of a $Beta(1,1)$ distribution.
#
# *Hint*: preliZ has built in function that does this for you.

# %%
data0 = pz.Beta(alpha=1,beta=1)
data0.kurtosis(),data0.mean(),data0.skewness(),data0.var()
# Out:
# (-1.2, 0.5, array(0.), 0.08333333333333333)

# %% [markdown]
# **Task3**:
#
# Plot the following distributions: $Beta(1,1)$, $Beta(0.9,0.9)$, $Beta(2,1)$, $Beta(1,2)$, $Beta(7,11)$, $Beta(96,42)$, $Beta(5,5)$, $Beta(500,500)$, $Beta(0.8,0.9)$.
#
# Then, determine which of those distribtuions has:
# - the largest/smallest mean
# - the largest/smallest variance
# - the largest/smallest skew
# - the largest/smallest kurtosis

# %%
pz.Beta(alpha=1,beta=1).plot_pdf()
pz.Beta(alpha=0.9,beta=0.9).plot_pdf()
pz.Beta(alpha=2,beta=1).plot_pdf()
pz.Beta(alpha=1,beta=2).plot_pdf()
pz.Beta(alpha=7,beta=11).plot_pdf()
pz.Beta(alpha=96,beta=42).plot_pdf()
pz.Beta(alpha=5,beta=5).plot_pdf()
pz.Beta(alpha=500,beta=500).plot_pdf()
pz.Beta(alpha=0.8,beta=0.9).plot_pdf()
# Out:
# <Axes: >

# %%
A = pz.Beta(alpha=1,beta=1)
B = pz.Beta(alpha=0.9,beta=0.9)
C = pz.Beta(alpha=2,beta=1)
D = pz.Beta(alpha=1,beta=2)
E = pz.Beta(alpha=7,beta=11)
F = pz.Beta(alpha=96,beta=42)
G = pz.Beta(alpha=5,beta=5)
H = pz.Beta(alpha=500,beta=500)
I = pz.Beta(alpha=0.8,beta=0.9)

# %%
A.kurtosis(), B.kurtosis(), C.kurtosis(), D.kurtosis(), E.kurtosis(), F.kurtosis(), G.kurtosis(), H.kurtosis, I.kurtosis()
# Out:
# (-1.2,
#  -1.2500000000000002,
#  -0.6,
#  -0.6,
#  -0.22931354359925787,
#  -0.011997937472861485,
#  -0.46153846153846156,
#  <bound method Beta.kurtosis of Beta(alpha=500, beta=500)>,
#  -1.263657274295572)

# %% [markdown]
# As we see from the output, Graph I has the lowest Kurtosis, while Graph G has the highest Kurtosis

# %%
A.skewness(), B.skewness(), C.skewness(), D.skewness(), E.skewness(), F.skewness(), G.skewness(), H.skewness(), I.skewness()
# Out:
# (array(0.),
#  array(0.),
#  -0.565685424949238,
#  0.565685424949238,
#  0.1986970545340808,
#  -0.14323292412687752,
#  array(0.),
#  array(0.),
#  0.1046752255731734)

# %% [markdown]
# As we see from the output, Graph C has the lowest skew, while Graph D has the highest skew

# %%
A.mean(), B.mean(), C.mean(), D.mean(), E.mean(), F.mean(), G.mean(), H.mean(), I.mean()
# Out:
# (0.5,
#  0.5,
#  0.6666666666666666,
#  0.3333333333333333,
#  0.3888888888888889,
#  0.6956521739130435,
#  0.5,
#  0.5,
#  0.47058823529411764)

# %% [markdown]
# As we see from the output, Graph D has the lowest mean, while Graph F has the highest mean

# %%
A.var(), B.var(), C.var(), D.var(), E.var(), F.var(), G.var(), H.var(), I.var()
# Out:
# (0.08333333333333333,
#  0.0892857142857143,
#  0.05555555555555555,
#  0.05555555555555555,
#  0.012508122157244964,
#  0.0015231670995906488,
#  0.022727272727272728,
#  0.00024975024975024975,
#  0.09227220299884659)

# %% [markdown]
# As we can see from the output, Graph H has the lowest variation, while Graph I has the most variation

# %% [markdown]
# ###Playing with other Continuous Distributions
#
# For the remaining tasks, make sure to continue to use the [preliZ documentation](https://preliz.readthedocs.io/en/latest/api_reference.html).
#
# The [wikipedia pages for each of the probability distributions](https://en.wikipedia.org/wiki/List_of_probability_distributions) are also great resources.
#
# [Wolfram Alpha](https://www.wolframalpha.com/examples/mathematics/probability/probability-distributions) is another great resource as well.

# %% [markdown]
# **Task4**:
#
# Plot the pdfs of each of the following distributions: $Normal(μ=0,σ=1)$, $StudentT(ν=1,μ=0,σ=1)$, $Exponential(λ=1/2)$, $Gamma(α=2,β=1)$, $HalfStudentT(ν=1,σ1)$
#
# For the T distribution, use
#
# ```
# support=(-4,4)
# ```
# inside the plot_pdf function.

# %%
pz.distributions.normal.Normal(mu=0, sigma=1).plot_pdf()
pz.distributions.studentt.StudentT(nu=1, mu=0, sigma=1).plot_pdf(support=(-4,4))
pz.distributions.exponential.Exponential(lam=1/2).plot_pdf()
pz.distributions.gamma.Gamma(alpha=2, beta=1).plot_pdf()
pz.distributions.halfstudentt.HalfStudentT(nu=1, sigma=1).plot_pdf(support=(-4,4))
# Out:
# <Axes: >

# %% [markdown]
# **Task5**:
#
# What x values do the Exponenital, Gamma, HalfSutdentT, and HalfNormal functions support? What x values do the Normal and T distribution support? What x values does the Beta distribution support?

# %% [markdown]
# *   Exponential, Gamma, HalfStudentT, HalfNormal - [0, ∞]
# *   Normal, T-distribution -  [-∞, ∞]
# *   Beta - [0, 1]

# %% [markdown]
# **Task6**:
#
# Can a distribution with support $[0,∞]$ have negative (or left) skew? If so, plot that specific distribution.

# %%
pz.distributions.weibull.Weibull(alpha=10,beta=1).plot_pdf(support=(0,float('inf')))
#Yeshi helped with this
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/function_base.py:158: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# /usr/local/lib/python3.10/dist-packages/numba/np/ufunc/dufunc.py:287: RuntimeWarning: divide by zero encountered in nb_logpdf
#   return super().__call__(*args, **kws)
# /usr/local/lib/python3.10/dist-packages/numba/np/ufunc/dufunc.py:287: RuntimeWarning: invalid value encountered in nb_logpdf
#   return super().__call__(*args, **kws)
# <Axes: >

# %% [markdown]
# **Task7**:
#
# Name a distribution that supports the real numbers with variance equal to 1, 0 skew, and 0 kurtosis.

# %% [markdown]
# 0 Skew - Centered graph
#
# 1 Variance - Normal Distribution
#
# 0 Kurtosis - Normal Distribution

# %%
pz.distributions.normal.Normal(mu=0, sigma=1).plot_pdf()
# Out:
# <Axes: >

# %%
normal=pz.distributions.normal.Normal(mu=0, sigma=1)
normal.var(),normal.skewness(),normal.kurtosis()
# Out:
# (1.0, 0, 0)

# %% [markdown]
# **Task8**:
#
# Name a distribution with support $(-∞,∞)$ and that has negative skew.

# %%
pz.SkewNormal(mu=0, sigma=1, alpha=-4).plot_pdf(support=(-5, 5))
# Out:
# <Axes: >

# %% [markdown]
# ###Playing with Discrete Distributions

# %% [markdown]
# **Task9**:
#
# Plot the pdfs (techincally the pmfs) of the following distributions: $Bernoulli(p=0.7)$, $Binomial(n=10,p=0.7)$, $Poisson(λ=7)$, $Geometric(p=0.7)$, $HyperGeometric(N=50,k=35,n=15)$, $Categorical(p=[0.05,0.3,0.05,0.1,0.2,0.4])$
#
# Additionally, compute the first four moments for all those distributions--except the Categorical distribution.

# %%
pz.distributions.bernoulli.Bernoulli(p=0.7).plot_pdf(support=(0,5))
pz.distributions.binomial.Binomial(n=10, p=0.7).plot_pdf(support=(0,5))
pz.distributions.poisson.Poisson(mu=7).plot_pdf(support=(0,5))
pz.distributions.geometric.Geometric(p=0.7).plot_pdf(support=(0,5))
pz.distributions.hypergeometric.HyperGeometric(N=50,k=35,n=15).plot_pdf(support=(0,5))
pz.distributions.categorical.Categorical(p=[0.05,0.3,0.05,0.1,0.2,0.4]).plot_pdf()
# Out:
# <Axes: >

# %%
qa = pz.distributions.bernoulli.Bernoulli(p=0.7)
qb = pz.distributions.binomial.Binomial(n=10, p=0.7)
qc = pz.distributions.poisson.Poisson(mu=7)
qd = pz.distributions.geometric.Geometric(p=0.7)
qe = pz.distributions.hypergeometric.HyperGeometric(N=50,k=35,n=15)
qf = pz.distributions.categorical.Categorical(p=[0.05,0.3,0.05,0.1,0.2,0.4])

# %%
qa.mean(), qb.mean(), qc.mean(), qd.mean(), qe.mean()
# Out:
# (0.7, 7.0, 7.0, 1.4285714285714286, 10.5)

# %%
qa.kurtosis(), qb.kurtosis(), qc.kurtosis(), qd.kurtosis(), qe.kurtosis()
# Out:
# (-1.238095238095238,
#  -0.12380952380952379,
#  0.14285714285714285,
#  7.633333333333333,
#  -0.08983451536643026)

# %%
qa.skewness(), qb.skewness(), qc.skewness(), qd.skewness(), qe.skewness()
# Out:
# (-0.8728715609439692,
#  -0.27602622373694163,
#  0.3779644730092272,
#  2.3734644158557194,
#  -0.1111111111111111)

# %%
qa.var(), qb.var(), qc.var(), qd.var(), qe.var()
# Out:
# (0.21000000000000002, 2.1000000000000005, 7.0, 0.6122448979591838, 2.25)

# %% [markdown]
# **Task10**:
#
# Describe what processes "generate" each of the previous discrete distributions models. Also report their support.
#
# Here's a spicier way to phrase the question: describe these distributions' maximum entropy conditions in english.
#
# Hint: Make sure to read any of the: preliZ documentation, relevant wikipedia articles, or wolfram alpha.

# %% [markdown]
# *   Bernoulli
#   * Support: [0,1]
#   * Process: Models a single trial with a binary outcome (success or failure).
#   * Max Entropy: Maximum entropy occurs at p = 0.5 because the outcome is most uncertain when both success and failure are equally likely.
#
# *   Binomial
#   * Support: {0,1,2, ... ,10}
#   * Process: Models the number of successes in n independent trials.
#   * Max Entropy: Maximum entropy occurs when p=0.5, meaning each trial is as uncertain as possible.
# *   Poisson
#   * Support: {0,1,2,…}
#   * Process: Models the number of events occurring in a fixed interval with a constant average rate λ.
#   * Max Entropy: For a given mean λ, entropy is maximized because the Poisson distribution is fully determined by its mean.
# *   Geometric:
#   * Support: {1,2,3,…}
#   * Process: Models the number of trials needed to get the first success in independent trials.
#   *Max Entropy: Maximum entropy occurs at p = 0.5, where the uncertainty about when the first success will happen is highest.
# *   Hypergeometric
#   * Support: max(0,N−b) and min(N,a)
#   * Process: Models the number of successes in a sample drawn without replacement from a population.
#   * Max Entropy: Maximum entropy occurs when the proportion of successes in the population (k/N) is around 0.5, as this results in the greatest uncertainty when sampling.
# *   Categorical
#   * Support: {1, 2, ..., k}
#   * Process: Models a single trial with k possible outcomes, each with different probabilities.
#   * Max Entropy: Entropy is maximized when all probabilities are equal, meaning each outcome is equally likely.
